# %% [markdown]
# # Training Moderasi Gambar (YOLO11-cls 3 kelas)
#
# **Sebelum mulai:** dari PC-mu, zip 3 folder dataset sumber menjadi **`dataset_sources.zip`** dengan struktur:
# ```
# dataset_sources.zip
#   dataset_obat_aborsi_google/...
#   dataset_normal/...
#   dataset_dokumen/...
# ```
# Cara (Windows): pilih ketiga folder di Desktop → klik kanan → *Send to → Compressed (zipped) folder*, lalu rename jadi `dataset_sources.zip`.

# %%
# 1. Clone repo (Ganti REPO_URL kalau repo private pakai token/SSH)
# !git clone https://github.com/sultansyah/moderasi-satudata-ml.git
# %cd /content/moderasi-satudata-ml

# %%
# 2. Install dependensi
# !pip install -q ultralytics pillow

# %%
# 3. Upload dataset_sources.zip (akan muncul dialog pilih file)
from google.colab import files
import zipfile, os

uploaded = files.upload()
for name in uploaded:
    with zipfile.ZipFile(name) as z:
        z.extractall('/content')
        print('Extracted:', z.namelist()[:3], '...')
# !ls /content | head

# %%
# 4. Bangun dataset + augmentasi (sesuaikan path kalau nama folder beda)
# !python prepare_dataset.py \
    --sources "obat_aborsi=/content/dataset_obat_aborsi_google;normal=/content/dataset_normal;dokumen=/content/dataset_dokumen" \
    --aug 2

# %%
# 5. TRAINING (pakai GPU otomatis: --device auto)
# !python train.py --device auto --epochs 40

# %%
# 6. Salin ke models/best.pt, zip, dan unduh ke PC
# !cp runs/yolo11n-cls-mod-v5/weights/best.pt models/best.pt

import zipfile
with zipfile.ZipFile('best.pt.zip', 'w') as z:
    z.write('models/best.pt', 'best.pt')

from google.colab import files
files.download('best.pt.zip')

# Sesudah terunduh: taruh di project lokal jadi models/best.pt, lalu git commit & push + deploy di VPS.
